# %%
#Zomato Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataframe = pd.read_csv("/content/Zomato Data Analysis Project - Colab-1.pdf")
print (dataframe)

# %%
dataframe

# %%
print(dataframe.info())

# %% [markdown]
# #Type of restaurents

# %%
dataframe.head()

# %%
sns.countplot(x=dataframe['listed_in(type)'])
plt.xlabel('Type of Restaurant')
plt.ylabel('Count')

# %%
dataframe.head()

# %% [markdown]
# #votes recieved from customers

# %%
group_data =dataframe.groupby('listed_in(type)')['votes'].sum()
result= pd.DataFrame({'votes': group_data})
plt.plot(result, c="g", marker="o")
plt.xlabel("Type of restaurant", c="red", size=20)
plt.ylabel("Votes", c="red", size=20)
plt.grid(True)

# %%
#conclusion - dinning restaurents has recieved maximum votes

# %%
dataframe.head()

# %% [markdown]
# #Ratings that majority of customers recieved!

# %%
plt.hist(dataframe['rate'], bins=4, edgecolor='black', rwidth=12)
plt.xlabel('Rating')
plt.ylabel('Frequency')

# %%
plt.hist(dataframe['rate'], bins=4, edgecolor='black', rwidth=12)
plt.xlabel('Rating')
plt.ylabel('Frequency')

# %%
#conclusion - majority restaurents recieved ratings from 3.5 to 4

# %%
dataframe.head()

# %% [markdown]
# #Avg order spending by couples

# %%
couple_data = dataframe['approx_cost(for two people)']
sns.countplot(x=couple_data)

# %% [markdown]
# conclusion - the majority of couples preferr restaurents with an approximate cost of 300 rupees

# %% [markdown]
# #which mode recieves max rating

# %%
dataframe.head()

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(x='online_order', y='rate', data=dataframe)

# %%
plt.figure(figsize=(7, 7))
sns.boxplot(x='online_order', y='rate', data=dataframe)

# %% [markdown]
# conclusion - offline order recieved lower rating comparison to online order

# %%
dataframe.head()

# %%
pivot_table = dataframe.pivot_table(index='listed_in(type)', columns='online_order',aggfunc='size', fill_value=0)
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt='d')
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()
